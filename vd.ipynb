# %%
import pandas as pd

# %%
df = pd.read_parquet("data/vehicle_data.parquet")

# %%
df = df[["make", "model", "year", "comb08u", "fueltype1"]]

# %%
df[df["comb08u"] == 0]
# Out:
#             make               model        year  comb08u         fueltype1
# 4         Toyota            Cressida  1987-01-01      0.0  Premium Gasoline
# 8      Chevrolet      R10 Pickup 2WD  1987-01-01      0.0  Regular Gasoline
# 14         Buick             Skyhawk  1988-01-01      0.0  Regular Gasoline
# 16     Chevrolet  Lumina Minivan 2WD  1996-01-01      0.0  Regular Gasoline
# 17        Toyota            RAV4 4WD  1998-01-01      0.0  Regular Gasoline
# ...          ...                 ...         ...      ...               ...
# 47518  Chevrolet               Prizm  2002-01-01      0.0  Regular Gasoline
# 47519        GMC          Sonoma 2WD  2003-01-01      0.0  Regular Gasoline
# 47520       Ford     F150 Pickup 4WD  1990-01-01      0.0  Regular Gasoline
# 47521    Hyundai               Excel  1992-01-01      0.0  Regular Gasoline
# 47522        GMC       G35 Rally 2WD  1992-01-01      0.0  Regular Gasoline
#
# [29656 rows x 5 columns]
